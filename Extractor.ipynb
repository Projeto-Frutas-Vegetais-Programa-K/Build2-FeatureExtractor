# %% [markdown]
# # Extração de features e organização em tabela

# %% [markdown]
# ResNet-50 é um modelo de rede neural convolucional (CNN) profunda e pré-treinado desenvolvido pela Microsoft Research Asia para classificação de imagens. "ResNet" significa "rede residual", e o número "50" se refere ao número de camadas da rede.
#
# O ResNet-50 tem sido amplamente utilizado em tarefas de classificação de imagens em diversos domínios, incluindo visão computacional, reconhecimento de objetos e reconhecimento de faces.
#
# Um dos objetivos deste notebook é demonstrar a utilização da rede ResNet50 para garantir, entre outras coisas, um treinamento rápido de um modelo de IA, assim como diminuir consideravelmente a necessidade de recursos computacionais.
#
# Aqui extraímos as features de imagens utilizando Resnet50 de múltiplos datasets:

# %%
import feature_extractor
# Out:
# 2023-08-08 16:01:54.933903: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-08 16:01:56.341651: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-08 16:01:56.575402: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...
